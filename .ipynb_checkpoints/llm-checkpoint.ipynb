# %%
#!pip install dateparser

# %% [markdown]
# # ----------------------------------------------
# # 1. Cargar librerías
# # ----------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import openai
import time

# %%
from openai import OpenAI
import os

# Inicializar cliente con tu API Key (usando variable de entorno)
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# %% [markdown]
# 🧪 Verificación rápida

# %%
import os
print("OPENAI_API_KEY" in os.environ)
# Out:
# True

# %%
import openai

openai.api_key = "OPENAI_API_KEY"

try:
    models = openai.models.list()
    print("✅ Tu API key es válida. Modelos disponibles:")
    for model in models['data']:
        print("-", model.id)
except Exception as e:
    print("❌ Error al verificar la API Key:")
    print(e)
# Out:
# ❌ Error al verificar la API Key:
# Error code: 401 - {'error': {'message': 'Incorrect API key provided: OPENAI_A**_KEY. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %% [markdown]
# # ----------------------------------------------
# # 2. Cargar tu archivo original
# # ----------------------------------------------

# %%
# Asegúrate que tu archivo esté en el mismo directorio
df = pd.read_csv("llm_input_text_dataset.csv")  # Debe contener una columna 'text' y 'date'

# Inicializar columnas para los resultados
df["fiscal_risk_score"] = None        # Puntaje del 1 al 5
df["risk_index"] = None               # Normalizado a escala 0.0–1.0

# %%
# Asegurar columnas necesarias
assert 'text' in df.columns, "Falta columna 'text' con los párrafos"
assert 'date' in df.columns, "Falta columna 'date' con la fecha del documento"

# %%
df.head(20)
# Out:
#                                                 title doc_type  doc_id  year  \
# 0   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 1   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 2   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 3   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 4   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 5   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 6   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 7   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 8   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 9   Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 10  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 11  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 12  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 13  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 14  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 15  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 16  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 17  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 18  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 19  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
#
#           date  page  paragraph_id  \
# 0   2016-01-28     1             3
# 1   2016-01-28     1             4
# 2   2016-01-28     1             5
# 3   2016-01-28     1             6
# 4   2016-01-28     1             7
# 5   2016-01-28     1            10
# 6   2016-01-28     2             1
# 7   2016-01-28     2             2
# 8   2016-01-28     2             8
# 9   2016-01-28     2             9
# 10  2016-01-28     2            11
# 11  2016-01-28     2            12
# 12  2016-01-28     3            15
# 13  2016-01-28     3            16
# 14  2016-01-28     3            17
# 15  2016-01-28     3            18
# 16  2016-01-28     4            13
# 17  2016-01-28     4            14
# 18  2016-04-15     1             7
# 19  2016-04-15     1            10
#
#                                                  text fiscal_risk_score  \
# 0   En ese sentido, el Consejo Fiscal, en reunione...              None
# 1   De acuerdo a lo señalado por el MEF, es necesa...              None
# 2   Por otro lado, mediante la Cuadragésima Tercer...              None
# 3   En virtud de la Segunda Disposición Complement...              None
# 4   Opinión del Consejo Fiscal sobre la nueva meto...              None
# 5   El presente informe contiene la opinión técnic...              None
# 6   Asimismo, en cuanto al proceso de revisión y a...              None
# 7   El Consejo Fiscal coincide con el MEF en que l...              None
# 8   Respecto a la metodología de cálculo del resul...              None
# 9   Índices de precios de minerales y de hidrocarb...              None
# 10  De esta forma se pueden reducir posibles error...              None
# 11  Sin embargo, el Consejo Fiscal considera neces...              None
# 12  Elasticidad de la relación entre los ingresos ...              None
# 13  Indicador tendencial de los índices de precios...              None
# 14  Nivel potencial del PBI En relación al cálculo...              None
# 15  Por otro lado, el Consejo Fiscal sugiere evalu...              None
# 16  Teniendo en cuenta lo expuesto, el Consejo Fis...              None
# 17  Finalmente, el Consejo Fiscal considera necesa...              None
# 18  Opinión del Consejo Fiscal sobre el Marco Macr...              None
# 19  El presente informe contiene la opinión del Co...              None
#
#    risk_index
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None

# %%
df["date"].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## to date

# %%
import pandas as pd

def convert_date_column(df):
    """
    Convierte la columna 'date' a tipo datetime si existe en el DataFrame.
    
    Argumento:
    - df: pandas.DataFrame
    
    Retorna:
    - df: pandas.DataFrame con la columna 'date' convertida, si corresponde.
    """
    if 'date' in df.columns:
        df['date'] = pd.to_datetime(df['date'], errors='coerce')
    return df

# %%
df = convert_date_column(df)

# %%
df["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.head(10)
# Out:
#                                                title doc_type  doc_id  year  \
# 0  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 1  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 2  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 3  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 4  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 5  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 6  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 7  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 8  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 9  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
#
#         date  page  paragraph_id  \
# 0 2016-01-28     1             3
# 1 2016-01-28     1             4
# 2 2016-01-28     1             5
# 3 2016-01-28     1             6
# 4 2016-01-28     1             7
# 5 2016-01-28     1            10
# 6 2016-01-28     2             1
# 7 2016-01-28     2             2
# 8 2016-01-28     2             8
# 9 2016-01-28     2             9
#
#                                                 text fiscal_risk_score  \
# 0  En ese sentido, el Consejo Fiscal, en reunione...              None
# 1  De acuerdo a lo señalado por el MEF, es necesa...              None
# 2  Por otro lado, mediante la Cuadragésima Tercer...              None
# 3  En virtud de la Segunda Disposición Complement...              None
# 4  Opinión del Consejo Fiscal sobre la nueva meto...              None
# 5  El presente informe contiene la opinión técnic...              None
# 6  Asimismo, en cuanto al proceso de revisión y a...              None
# 7  El Consejo Fiscal coincide con el MEF en que l...              None
# 8  Respecto a la metodología de cálculo del resul...              None
# 9  Índices de precios de minerales y de hidrocarb...              None
#
#   risk_index
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None

# %% [markdown]
# # ----------------------------------------------
# # 3. Función para obtener score desde GPT (1–5)
# # ----------------------------------------------

# %%
context = """
Sabemos que desde aproximadamente 2016 el manejo de las finanzas públicas ha mostrado signos crecientes de deterioro. 
La pérdida de disciplina fiscal, la falta de transparencia y el relajamiento de las reglas fiscales han sido temas 
recurrentes en los informes del Consejo. A ello se suma el impacto de la inestabilidad política —con frecuentes cambios 
ministeriales— sobre la capacidad institucional para llevar una política fiscal prudente y sostenible. En este contexto, 
el Consejo ha venido alertando con más frecuencia y firmeza sobre el incumplimiento de metas fiscales, el deterioro del 
balance público, y los riesgos de un endeudamiento creciente y potencialmente insostenible.

Criterios comunes en los informes del Consejo Fiscal (según categoría):

1. Cumplimiento y disciplina fiscal:
(disciplina fiscal, incumplimiento de metas fiscales, relajamiento de reglas fiscales, uso inadecuado del gasto público, desviación del déficit fiscal, deterioro del marco fiscal, flexibilización sin justificación, política fiscal procíclica)

2. Riesgo y sostenibilidad:
(riesgo fiscal, riesgo de sostenibilidad de la deuda, endeudamiento excesivo, dependencia de ingresos extraordinarios, vulnerabilidad fiscal estructural, uso de medidas transitorias o no permanentes, incertidumbre macrofiscal)

3. Gobernanza e institucionalidad:
(transparencia fiscal, calidad del gasto público, incertidumbre institucional, falta de planificación multianual, cambios frecuentes en autoridades económicas, debilitamiento institucional, independencia fiscal comprometida, ausencia de reforma estructural)
"""

# %% [markdown]
#     """
#     Evalúa un párrafo de un informe fiscal utilizando GPT-4o y asigna un score del 1 al 5
#     según el nivel de preocupación o alarma fiscal expresado.
#
#     Returns:
#         - int (1 a 5): Score de riesgo fiscal asignado por el modelo
#         - None: En caso de error o respuesta inválida
#     """

# %% [markdown]
# Interpretación:
# - 1 = Sin preocupación fiscal (consolidación fiscal sostenida, cumplimiento de metas, transparencia fiscal, calidad del gasto público, planificación multianual)
# - 2 = Ligera preocupación (observaciones menores, advertencias marginales, riesgo fiscal potencial, uso de medidas transitorias o ingresos extraordinarios)
# - 3 = Neutral (descripción técnica sin énfasis positivo ni negativo, gestión fiscal dentro del marco previsto)
# - 4 = Alta preocupación (incumplimiento de metas, flexibilización sin justificación, incertidumbre macrofiscal, debilitamiento institucional)
# - 5 = Alarma fiscal (críticas severas, endeudamiento excesivo, deterioro del marco fiscal, independencia fiscal comprometida)

# %%
def get_llm_score(text):
    prompt = f"""
Eres un analista técnico del Consejo Fiscal de Perú. Evalúa el siguiente párrafo extraído de un informe técnico del Consejo Fiscal (CF), donde se emite una opinión sobre el desempeño fiscal del Ministerio de Economía y Finanzas (MEF) en cuanto al cumplimiento de las metas fiscales.

Tu tarea es asignar un **puntaje del 1 al 5** según el **nivel de preocupación o alerta fiscal expresado en el texto**.

Interpretación:
- 1 = Sin preocupación fiscal (cumplimiento de metas, transparencia fiscal, planificación multianual)
- 2 = Ligera preocupación (riesgo fiscal potencial, desviación del déficit, dependencia de ingresos extraordinarios)
- 3 = Neutral (descripción técnica, gestión dentro del marco, sin juicio valorativo)
- 4 = Alta preocupación (incumplimiento de metas, relajamiento fiscal, incertidumbre macroeconómica)
- 5 = Alarma fiscal (críticas severas, riesgo de sostenibilidad de la deuda, independencia fiscal comprometida)

Devuelve solo un número del 1 al 5.

Texto:
\"\"\"{text}\"\"\"
""".strip()

    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}],
            temperature=0,
            max_tokens=5,
        )
        result = response.choices[0].message.content.strip()
        if result in {'1', '2', '3', '4', '5'}:
            return int(result)
        else:
            print(f"⚠️ Respuesta inesperada: {result}")
            return None
    except Exception as e:
        print(f"❌ Error: {e}")
        return None

# %% [markdown]
# # ----------------------------------------------
# # 4. Ejecutar clasificación (con backup y control de crédito)
# # ----------------------------------------------

# %%
import openai
print(openai.__version__)
# Out:
# 1.91.0

# %%
from datetime import datetime

start = time.time()

for i, row in df.iterrows():
    if pd.notna(row["fiscal_risk_score"]):
        continue  # Ya procesado

    score = get_llm_score(row["text"])

    # Guardar score
    df.at[i, "fiscal_risk_score"] = score
    df.at[i, "risk_index"] = score / 5 if score else None

    # Backup cada 10 filas
    if i % 10 == 0:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# 💾 Backup guardado en fila 1670 - 20250716_150149
# 💾 Backup guardado en fila 1680 - 20250716_150208
# 💾 Backup guardado en fila 1690 - 20250716_150226
# 💾 Backup guardado en fila 1700 - 20250716_150245
# 💾 Backup guardado en fila 1710 - 20250716_150302
# 💾 Backup guardado en fila 1720 - 20250716_150320
# 💾 Backup guardado en fila 1730 - 20250716_150338
# 💾 Backup guardado en fila 1740 - 20250716_150357
# 💾 Backup guardado en fila 1750 - 20250716_150415
# 💾 Backup guardado en fila 1760 - 20250716_150434
# 💾 Backup guardado en fila 1770 - 20250716_150452
# 💾 Backup guardado en fila 1780 - 20250716_150513
# 💾 Backup guardado en fila 1790 - 20250716_150532
# 💾 Backup guardado en fila 1800 - 20250716_150550
# 💾 Backup guardado en fila 1810 - 20250716_150609
# 💾 Backup guardado en fila 1820 - 20250716_150627
# 💾 Backup guardado en fila 1830 - 20250716_150645
# 💾 Backup guardado en fila 1840 - 20250716_150703
# 💾 Backup guardado en fila 1850 - 20250716_150721
# 💾 Backup guardado en fila 1860 - 20250716_150739
# 💾 Backup guardado en fila 1870 - 20250716_150758
# 💾 Backup guardado en fila 1880 - 20250716_150816
# 💾 Backup guardado en fila 1890 - 20250716_150835
# 💾 Backup guardado en fila 1900 - 20250716_150854
# 💾 Backup guardado en fila 1910 - 20250716_150911
# 💾 Backup guardado en fila 1920 - 20250716_150929
# 💾 Backup guardado en fila 1930 - 20250716_150946
# 💾 Backup guardado en fila 1940 - 20250716_151005
# ✅ Proceso completado en 73.05 minutos.

# %% [markdown]
# # Guardar resultados completos

# %%
df.to_csv("df_fiscal_scored.csv", index=False)

# %%
df.head(5)
# Out:
#                                                title doc_type  doc_id  year  \
# 0  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 1  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 2  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 3  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
# 4  Informe CF N° 001-2016 – Opinión del Consejo F...  Informe     1.0  2016
#
#         date  page  paragraph_id  \
# 0 2016-01-28     1             3
# 1 2016-01-28     1             4
# 2 2016-01-28     1             5
# 3 2016-01-28     1             6
# 4 2016-01-28     1             7
#
#                                                 text fiscal_risk_score  \
# 0  En ese sentido, el Consejo Fiscal, en reunione...                 3
# 1  De acuerdo a lo señalado por el MEF, es necesa...                 2
# 2  Por otro lado, mediante la Cuadragésima Tercer...                 3
# 3  En virtud de la Segunda Disposición Complement...                 3
# 4  Opinión del Consejo Fiscal sobre la nueva meto...                 3
#
#   risk_index
# 0        0.6
# 1        0.4
# 2        0.6
# 3        0.6
# 4        0.6

# %% [markdown]
# # Fleeting inspect

# %%
df["fiscal_risk_score"].value_counts(dropna=False).sort_index()
# Out:
# fiscal_risk_score
# 1       143
# 2       472
# 3       555
# 4       693
# 5        79
# None      1
# Name: count, dtype: int64

# %%
df["risk_index"].describe()
# Out:
# count     1942.0
# unique       5.0
# top          0.8
# freq       693.0
# Name: risk_index, dtype: float64

# %% [markdown]
# # ----------------------------------------------
# # 5. Agregar score promedio por fecha
# # ----------------------------------------------

# %% [markdown]
# # Aggregation

# %%
df_doc_avg = df.groupby(['title', 'date']).agg(
    avg_risk_score=('fiscal_risk_score', 'mean'),
    avg_risk_index=('risk_index', 'mean'),
    n_paragraphs=('fiscal_risk_score', 'count')
).reset_index()

# %%
df_doc_avg
# Out:
#                                                 title       date  \
# 0   Comunicado N° 01-2022-CF Comunicado del Consej... 2022-01-14
# 1   Comunicado N° 01-2023-CF Comunicado del Consej... 2023-03-02
# 2   Comunicado N° 01-2024-CF – El Consejo Fiscal a... 2024-02-01
# 3   Comunicado N° 01-2025-CF – El Consejo Fiscal e... 2025-01-20
# 4   Comunicado N° 02-2022-CF Comunicado del Consej... 2022-05-24
# ..                                                ...        ...
# 67  Informe N° 05-2024-CF – Opinión del Consejo Fi... 2024-08-23
# 68  Informe N° 06-2021-CF Opinión del Consejo Fisc... 2021-12-20
# 69  Informe N°002-2019-CF Opinión del Consejo Fisc... 2019-05-21
# 70  Informe N°003-2019-CF Opinión del Consejo Fisc... 2019-06-06
# 71  Informe N°004-2019-CF Opinión del Consejo Fisc... 2019-08-26
#
#    avg_risk_score avg_risk_index  n_paragraphs
# 0        4.285714       0.857143             7
# 1             3.0            0.6             6
# 2        3.846154       0.769231            13
# 3        3.645161       0.729032            31
# 4             4.4           0.88             5
# ..            ...            ...           ...
# 67       3.319444       0.663889            72
# 68         2.8125         0.5625            32
# 69            2.7           0.54            40
# 70       2.612903       0.522581            31
# 71       2.648148        0.52963            54
#
# [72 rows x 5 columns]

# %%
df_score_dist = (
    df.pivot_table(index=['title', 'date'], 
                   columns='fiscal_risk_score', 
                   values='text', 
                   aggfunc='count', 
                   fill_value=0)
    .reset_index()
    .rename(columns={1: 'score_1', 2: 'score_2', 3: 'score_3', 4: 'score_4', 5: 'score_5'})
)

# %%
df_score_dist
# Out:
# fiscal_risk_score                                              title  \
# 0                  Comunicado N° 01-2022-CF Comunicado del Consej...
# 1                  Comunicado N° 01-2023-CF Comunicado del Consej...
# 2                  Comunicado N° 01-2024-CF – El Consejo Fiscal a...
# 3                  Comunicado N° 01-2025-CF – El Consejo Fiscal e...
# 4                  Comunicado N° 02-2022-CF Comunicado del Consej...
# ..                                                               ...
# 67                 Informe N° 05-2024-CF – Opinión del Consejo Fi...
# 68                 Informe N° 06-2021-CF Opinión del Consejo Fisc...
# 69                 Informe N°002-2019-CF Opinión del Consejo Fisc...
# 70                 Informe N°003-2019-CF Opinión del Consejo Fisc...
# 71                 Informe N°004-2019-CF Opinión del Consejo Fisc...
#
# fiscal_risk_score       date  score_1  score_2  score_3  score_4  score_5
# 0                 2022-01-14        0        0        0        5        2
# 1                 2023-03-02        0        2        2        2        0
# 2                 2024-02-01        0        1        1       10        1
# 3                 2025-01-20        2        0        6       22        1
# 4                 2022-05-24        0        0        0        3        2
# ..                       ...      ...      ...      ...      ...      ...
# 67                2024-08-23        1       16       16       37        2
# 68                2021-12-20        0       13       12        7        0
# 69                2019-05-21        4       10       20        6        0
# 70                2019-06-06        7        6       10        8        0
# 71                2019-08-26        8       14       21       11        0
#
# [72 rows x 7 columns]

# %%
score_cols = ['score_1', 'score_2', 'score_3', 'score_4', 'score_5']
df_score_dist[score_cols] = df_score_dist[score_cols].div(df_score_dist[score_cols].sum(axis=1), axis=0)

# %%
df_score_dist
# Out:
# fiscal_risk_score                                              title  \
# 0                  Comunicado N° 01-2022-CF Comunicado del Consej...
# 1                  Comunicado N° 01-2023-CF Comunicado del Consej...
# 2                  Comunicado N° 01-2024-CF – El Consejo Fiscal a...
# 3                  Comunicado N° 01-2025-CF – El Consejo Fiscal e...
# 4                  Comunicado N° 02-2022-CF Comunicado del Consej...
# ..                                                               ...
# 67                 Informe N° 05-2024-CF – Opinión del Consejo Fi...
# 68                 Informe N° 06-2021-CF Opinión del Consejo Fisc...
# 69                 Informe N°002-2019-CF Opinión del Consejo Fisc...
# 70                 Informe N°003-2019-CF Opinión del Consejo Fisc...
# 71                 Informe N°004-2019-CF Opinión del Consejo Fisc...
#
# fiscal_risk_score       date   score_1   score_2   score_3   score_4   score_5
# 0                 2022-01-14  0.000000  0.000000  0.000000  0.714286  0.285714
# 1                 2023-03-02  0.000000  0.333333  0.333333  0.333333  0.000000
# 2                 2024-02-01  0.000000  0.076923  0.076923  0.769231  0.076923
# 3                 2025-01-20  0.064516  0.000000  0.193548  0.709677  0.032258
# 4                 2022-05-24  0.000000  0.000000  0.000000  0.600000  0.400000
# ..                       ...       ...       ...       ...       ...       ...
# 67                2024-08-23  0.013889  0.222222  0.222222  0.513889  0.027778
# 68                2021-12-20  0.000000  0.406250  0.375000  0.218750  0.000000
# 69                2019-05-21  0.100000  0.250000  0.500000  0.150000  0.000000
# 70                2019-06-06  0.225806  0.193548  0.322581  0.258065  0.000000
# 71                2019-08-26  0.148148  0.259259  0.388889  0.203704  0.000000
#
# [72 rows x 7 columns]

# %%
df_doc_summary = pd.merge(df_doc_avg, df_score_dist, on=['title', 'date'])

# %%
df_doc_summary
# Out:
#                                                 title       date  \
# 0   Comunicado N° 01-2022-CF Comunicado del Consej... 2022-01-14
# 1   Comunicado N° 01-2023-CF Comunicado del Consej... 2023-03-02
# 2   Comunicado N° 01-2024-CF – El Consejo Fiscal a... 2024-02-01
# 3   Comunicado N° 01-2025-CF – El Consejo Fiscal e... 2025-01-20
# 4   Comunicado N° 02-2022-CF Comunicado del Consej... 2022-05-24
# ..                                                ...        ...
# 67  Informe N° 05-2024-CF – Opinión del Consejo Fi... 2024-08-23
# 68  Informe N° 06-2021-CF Opinión del Consejo Fisc... 2021-12-20
# 69  Informe N°002-2019-CF Opinión del Consejo Fisc... 2019-05-21
# 70  Informe N°003-2019-CF Opinión del Consejo Fisc... 2019-06-06
# 71  Informe N°004-2019-CF Opinión del Consejo Fisc... 2019-08-26
#
#    avg_risk_score avg_risk_index  n_paragraphs   score_1   score_2   score_3  \
# 0        4.285714       0.857143             7  0.000000  0.000000  0.000000
# 1             3.0            0.6             6  0.000000  0.333333  0.333333
# 2        3.846154       0.769231            13  0.000000  0.076923  0.076923
# 3        3.645161       0.729032            31  0.064516  0.000000  0.193548
# 4             4.4           0.88             5  0.000000  0.000000  0.000000
# ..            ...            ...           ...       ...       ...       ...
# 67       3.319444       0.663889            72  0.013889  0.222222  0.222222
# 68         2.8125         0.5625            32  0.000000  0.406250  0.375000
# 69            2.7           0.54            40  0.100000  0.250000  0.500000
# 70       2.612903       0.522581            31  0.225806  0.193548  0.322581
# 71       2.648148        0.52963            54  0.148148  0.259259  0.388889
#
#      score_4   score_5
# 0   0.714286  0.285714
# 1   0.333333  0.000000
# 2   0.769231  0.076923
# 3   0.709677  0.032258
# 4   0.600000  0.400000
# ..       ...       ...
# 67  0.513889  0.027778
# 68  0.218750  0.000000
# 69  0.150000  0.000000
# 70  0.258065  0.000000
# 71  0.203704  0.000000
#
# [72 rows x 10 columns]

# %% [markdown]
# # ----------------------------------------------
# # 6. Visualizar índice fiscal
# # ----------------------------------------------

# %% [markdown]
# # CMA

# %%
df_doc_summary = df_doc_summary.sort_values("date")

# %%
# Calcula la media móvil centrada con ventana de 3 documentos
df_doc_summary["cma_risk_index"] = df_doc_summary["avg_risk_index"].rolling(window=3, center=True).mean()

# %% [markdown]
# $$
# \text{CMA}_t = \frac{4X_{t-1} + 2X_t + X_{t+1}}{7}
# $$

# %% [markdown]
# # Áreas apiladas

# %%
import numpy as np
import matplotlib.pyplot as plt

# Asegurar orden por fecha
df_doc_summary = df_doc_summary.sort_values("date").reset_index(drop=True)
df_doc_summary['date_str'] = df_doc_summary['date'].dt.strftime('%Y-%m-%d')

# Pesos del suavizamiento
weights = np.array([1, 2, 1])

# Aplicar CMA con bordes extendidos a cada score
for col in ['score_1', 'score_2', 'score_3', 'score_4', 'score_5']:
    series = df_doc_summary[col].copy()

    middle_cma = (
        series.rolling(window=3, center=True)
        .apply(lambda x: np.dot(x, weights) / 4, raw=True)
    )

    # Bordes
    first = series.iloc[0]
    second = series.iloc[1]
    first_smoothed = (3 * first + second) / 4

    last = series.iloc[-1]
    penultimate = series.iloc[-2]
    last_smoothed = (3 * last + penultimate) / 4

    # Insertar bordes
    middle_cma.iloc[0] = first_smoothed
    middle_cma.iloc[-1] = last_smoothed

    df_doc_summary[f'{col}_cma'] = middle_cma

# Configuración para el gráfico
cols_cma = ['score_1_cma', 'score_2_cma', 'score_3_cma', 'score_4_cma', 'score_5_cma']
labels = ['1 (bajo)', '2', '3', '4', '5 (alto)']
colors = ['#005f5e', '#00DFA2', '#FFF183', '#ff8575', '#E6004C']

# Gráfico de áreas apiladas suavizadas
plt.figure(figsize=(14, 6))
plt.stackplot(df_doc_summary['date_str'], 
              *[df_doc_summary[col] for col in cols_cma],
              labels=labels,
              colors=colors)

plt.ylabel("Proporción de Párrafos", fontsize=14)
plt.xticks(rotation=90)
plt.legend(loc='upper left')
plt.grid(True)
plt.tight_layout()

# Guardar gráfico
plt.savefig("stacked_areas.png", dpi=300)
plt.show()

# %% [markdown]
# # Index

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Calcular el índice promedio centrado
df_doc_summary["avg_risk_index_centered"] = df_doc_summary["avg_risk_index"] - 0.6

# 2. Aplicar suavizamiento CMA (1-2-1) con extremos refinados
weights = np.array([1, 2, 1])
series = df_doc_summary["avg_risk_index_centered"].copy()

# CMA centrado
cma = series.rolling(window=3, center=True).apply(lambda x: np.dot(x, weights)/4, raw=True)

# Bordes corregidos
first = series.iloc[0]
second = series.iloc[1]
cma.iloc[0] = (3 * first + second) / 4

last = series.iloc[-1]
penultimate = series.iloc[-2]
cma.iloc[-1] = (3 * last + penultimate) / 4

# Guardar resultado
df_doc_summary["avg_risk_index_centered_cma"] = cma

# 3. Graficar y guardar como PNG
plt.figure(figsize=(14, 6))

# Serie original (transparente)
plt.plot(df_doc_summary["date_str"], df_doc_summary["avg_risk_index_centered"],
         label="Índice Promedio Centrado", linestyle='--',
         marker='o', alpha=0.4, color="#cd301b")

# Serie suavizada
plt.plot(df_doc_summary["date_str"], df_doc_summary["avg_risk_index_centered_cma"],
         label="Índice de Tono Fiscal (CMA 1-2-1)", linewidth=2, color="#cd301b")

# Eje horizontal en cero
plt.axhline(0, color='black', linestyle=':', linewidth=1)

# Estética
plt.ylabel("Índice de Tono Fiscal", fontsize = 16)
plt.xticks(rotation=90)
plt.grid(True)
plt.legend()
plt.tight_layout()

# Guardar como PNG
plt.savefig("fiscal_tone_index.png", dpi=300)
#plt.close()
plt.show()
