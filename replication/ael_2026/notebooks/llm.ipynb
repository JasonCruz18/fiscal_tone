# %%
#!pip install dateparser

# %% [markdown]
# # ----------------------------------------------
# # 1. Cargar librerías
# # ----------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import openai
import time

# %%
from openai import OpenAI
import os

# Inicializar cliente con tu API Key (usando variable de entorno)
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# %% [markdown]
# 🧪 Verificación rápida

# %%
import os
print("OPENAI_API_KEY" in os.environ)
# Out:
# True

# %% [markdown]
# # ----------------------------------------------
# # 2. Cargar tu archivo original
# # ----------------------------------------------

# %%
# Asegúrate que tu archivo esté en el mismo directorio
df = pd.read_csv("../data/processed/llm_input_text_dataset_true.csv")  # Debe contener una columna 'text' y 'date'

# Inicializar columnas para los resultados
df["fiscal_risk_score"] = None        # Puntaje del 1 al 5
df["risk_index"] = None               # Normalizado a escala 0.0–1.0

# %%
# Asegurar columnas necesarias
assert 'text' in df.columns, "Falta columna 'text' con los párrafos"
assert 'date' in df.columns, "Falta columna 'date' con la fecha del documento"

# %%
df.head(20)
# Out:
#                                                 title doc_type  doc_id  year  \
# 0   Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 1   Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 2   Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 3   Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 4   Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 5   Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 6   Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 7   Informe CF N° 004-2016 – Opinión del Consejo F...  Informe     4.0  2016
# 8   Informe CF N° 004-2016 – Opinión del Consejo F...  Informe     4.0  2016
# 9   Informe CF N° 006-2016 – Opinión del Consejo F...  Informe     6.0  2016
# 10  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 11  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 12  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 13  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 14  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 15  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 16  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 17  Informe CF N° 007-2016 – Opinión del Consejo F...  Informe     7.0  2016
# 18  Informe CF N° 008-2016 – Opinión del Consejo F...  Informe     8.0  2016
# 19  Informe CF N° 008-2016 – Opinión del Consejo F...  Informe     8.0  2016
#
#           date  page  paragraph_id  \
# 0   2016-04-15     2            12
# 1   2016-04-15     3            13
# 2   2016-04-15     3            15
# 3   2016-06-23     3             2
# 4   2016-06-23     3            21
# 5   2016-06-23     4             5
# 6   2016-06-23     4            25
# 7   2016-08-18     1             6
# 8   2016-08-18     3            12
# 9   2016-08-26     6             4
# 10  2016-10-04     1             6
# 11  2016-10-04     2             5
# 12  2016-10-04     3             8
# 13  2016-10-04     3            21
# 14  2016-10-04     5            13
# 15  2016-10-04     6            28
# 16  2016-10-04     6            30
# 17  2016-10-04     7            29
# 18  2016-12-26     1            53
# 19  2016-12-26     2            54
#
#                                                  text fiscal_risk_score  \
# 0   Sin embargo, en relación a las previsiones de ...              None
# 1   Teniendo en cuenta lo expuesto, el CF opina qu...              None
# 2   El CF advierte que el escenario internacional ...              None
# 3   Por último, cabe indicar que el numeral 8.4 de...              None
# 4    El listado con los gobiernos regionales y loc...              None
# 5   El objetivo de las reglas fiscales establecida...              None
# 6   Sin embargo, en relación a los gobiernos regio...              None
# 7   En este entorno, la actividad económica local ...              None
# 8   Por otro lado, luego de un proceso de consolid...              None
# 9   El CF opina que la proyección de ingresos públ...              None
# 10  Por su parte, los lineamientos de política fis...              None
# 11  Se establece una trayectoria de reducción grad...              None
# 12  Opinión de CF sobre el proyecto de DPME El CF ...              None
# 13  Asegurar permanentemente la sostenibilidad fis...              None
# 14  Gestión de riesgos fiscales y sostenibilidad f...              None
# 15  Por otro lado, una adecuada gestión de riesgos...              None
# 16  En este sentido, el CF sugiere incorporar dent...              None
# 17  Teniendo en cuenta lo expuesto, el CF valora e...              None
# 18  Contenido de los proyectos de Decreto Legislat...              None
# 19  En esta línea, el MRTF-SPNF establece como pri...              None
#
#    risk_index
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None

# %%
df["date"].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## to date

# %%
import pandas as pd

def convert_date_column(df):
    """
    Convierte la columna 'date' a tipo datetime si existe en el DataFrame.
    
    Argumento:
    - df: pandas.DataFrame
    
    Retorna:
    - df: pandas.DataFrame con la columna 'date' convertida, si corresponde.
    """
    if 'date' in df.columns:
        df['date'] = pd.to_datetime(df['date'], errors='coerce')
    return df

# %%
df = convert_date_column(df)

# %%
df["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.head(10)
# Out:
#                                                title doc_type  doc_id  year  \
# 0  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 1  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 2  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 3  Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 4  Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 5  Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 6  Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 7  Informe CF N° 004-2016 – Opinión del Consejo F...  Informe     4.0  2016
# 8  Informe CF N° 004-2016 – Opinión del Consejo F...  Informe     4.0  2016
# 9  Informe CF N° 006-2016 – Opinión del Consejo F...  Informe     6.0  2016
#
#         date  page  paragraph_id  \
# 0 2016-04-15     2            12
# 1 2016-04-15     3            13
# 2 2016-04-15     3            15
# 3 2016-06-23     3             2
# 4 2016-06-23     3            21
# 5 2016-06-23     4             5
# 6 2016-06-23     4            25
# 7 2016-08-18     1             6
# 8 2016-08-18     3            12
# 9 2016-08-26     6             4
#
#                                                 text fiscal_risk_score  \
# 0  Sin embargo, en relación a las previsiones de ...              None
# 1  Teniendo en cuenta lo expuesto, el CF opina qu...              None
# 2  El CF advierte que el escenario internacional ...              None
# 3  Por último, cabe indicar que el numeral 8.4 de...              None
# 4   El listado con los gobiernos regionales y loc...              None
# 5  El objetivo de las reglas fiscales establecida...              None
# 6  Sin embargo, en relación a los gobiernos regio...              None
# 7  En este entorno, la actividad económica local ...              None
# 8  Por otro lado, luego de un proceso de consolid...              None
# 9  El CF opina que la proyección de ingresos públ...              None
#
#   risk_index
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None

# %% [markdown]
# # ----------------------------------------------
# # 3. Función para obtener score desde GPT (1–5)
# # ----------------------------------------------

# %%
context = """
Sabemos que desde aproximadamente 2016 el manejo de las finanzas públicas ha mostrado signos crecientes de deterioro. 
La pérdida de disciplina fiscal, la falta de transparencia y el relajamiento de las reglas fiscales han sido temas 
recurrentes en las opiniones del Consejo Fiscal. A ello se suma el impacto de la inestabilidad política —con frecuentes cambios 
ministeriales— sobre la capacidad institucional para llevar una política fiscal prudente y sostenible. En este contexto, 
el Consejo Fiscal ha venido alertando con más frecuencia y firmeza sobre el incumplimiento de metas fiscales, el deterioro del 
balance público, y los riesgos de un endeudamiento creciente y potencialmente insostenible.

Criterios comunes en los informes y comunicados del Consejo Fiscal (según categoría):

1. Cumplimiento y disciplina fiscal:
(disciplina fiscal, incumplimiento de metas fiscales, relajamiento de reglas fiscales, uso inadecuado del gasto público, desviación del déficit fiscal, deterioro del marco fiscal, flexibilización sin justificación, política fiscal procíclica)

2. Riesgo y sostenibilidad:
(riesgo fiscal, riesgo de sostenibilidad de la deuda, endeudamiento excesivo, dependencia de ingresos extraordinarios, vulnerabilidad fiscal estructural, uso de medidas transitorias o no permanentes, incertidumbre macrofiscal)

3. Gobernanza e institucionalidad:
(transparencia fiscal, calidad del gasto público, incertidumbre institucional, falta de planificación multianual, cambios frecuentes en autoridades económicas, debilitamiento institucional, independencia fiscal comprometida, ausencia de reforma estructural)
"""

# %% [markdown]
#     """
#     Evalúa un párrafo de un informe fiscal utilizando GPT-4o y asigna un score del 1 al 5
#     según el nivel de preocupación o alarma fiscal expresado.
#
#     Returns:
#         - int (1 a 5): Score de riesgo fiscal asignado por el modelo
#         - None: En caso de error o respuesta inválida
#     """

# %% [markdown]
# Interpretación:
# - 1 = Sin preocupación fiscal (consolidación fiscal sostenida, cumplimiento de metas, transparencia fiscal, calidad del gasto público, planificación multianual)
# - 2 = Ligera preocupación (observaciones menores, advertencias marginales, riesgo fiscal potencial, uso de medidas transitorias o ingresos extraordinarios)
# - 3 = Neutral (descripción técnica sin énfasis positivo ni negativo, gestión fiscal dentro del marco previsto)
# - 4 = Alta preocupación (incumplimiento de metas, flexibilización sin justificación, incertidumbre macrofiscal, debilitamiento institucional)
# - 5 = Alarma fiscal (críticas severas, endeudamiento excesivo, deterioro del marco fiscal, independencia fiscal comprometida)

# %%
def get_llm_score(text):
    prompt = f"""
Eres un analista técnico del Consejo Fiscal de Perú. Evalúa el siguiente párrafo extraído de un informe técnico del Consejo Fiscal (CF), donde se emite una opinión sobre el desempeño fiscal del Ministerio de Economía y Finanzas (MEF) en cuanto al cumplimiento de las metas fiscales.

Tu tarea es asignar un **puntaje del 1 al 5** según el **nivel de preocupación o alerta fiscal expresado en el texto**.

Interpretación:
- 1 = Sin preocupación fiscal (cumplimiento de metas, transparencia fiscal, planificación multianual)
- 2 = Ligera preocupación (riesgo fiscal potencial, desviación del déficit, dependencia de ingresos extraordinarios)
- 3 = Neutral (descripción técnica, gestión dentro del marco, sin juicio valorativo)
- 4 = Alta preocupación (incumplimiento de metas, relajamiento fiscal, incertidumbre macroeconómica)
- 5 = Alarma fiscal (críticas severas, riesgo de sostenibilidad de la deuda, independencia fiscal comprometida)

Devuelve solo un número del 1 al 5.

Texto:
\"\"\"{text}\"\"\"
""".strip()

    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}],
            temperature=0,
            max_tokens=5,
        )
        result = response.choices[0].message.content.strip()
        if result in {'1', '2', '3', '4', '5'}:
            return int(result)
        else:
            print(f"⚠️ Respuesta inesperada: {result}")
            return None
    except Exception as e:
        print(f"❌ Error: {e}")
        return None

# %% [markdown]
# ---
# # 4. Ejecutar clasificación (con backup y control de crédito)
# ---

# %%
import openai
print(openai.__version__)
# Out:
# 1.91.0

# %%
from datetime import datetime

start = time.time()

for i, row in df.iterrows():
    if pd.notna(row["fiscal_risk_score"]):
        continue  # Ya procesado

    score = get_llm_score(row["text"])

    # Guardar score
    df.at[i, "fiscal_risk_score"] = score
    df.at[i, "risk_index"] = score / 5 if score else None

    # Backup cada 250 filas
    if i % 250 == 0:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        df.to_csv(f"backup_fiscal_risk_{timestamp}.csv", index=False)
        print(f"💾 Backup guardado en fila {i} - {timestamp}")

    time.sleep(1.2)  # Control para no sobrecargar

end = time.time()
print(f"✅ Proceso completado en {round((end - start)/60, 2)} minutos.")
# Out:
# 💾 Backup guardado en fila 10 - 20251107_023838
# 💾 Backup guardado en fila 20 - 20251107_023858
# 💾 Backup guardado en fila 30 - 20251107_023920
# 💾 Backup guardado en fila 40 - 20251107_023939
# 💾 Backup guardado en fila 50 - 20251107_023957
# 💾 Backup guardado en fila 60 - 20251107_024016
# 💾 Backup guardado en fila 70 - 20251107_024034
# 💾 Backup guardado en fila 80 - 20251107_024054
# 💾 Backup guardado en fila 90 - 20251107_024113
# 💾 Backup guardado en fila 100 - 20251107_024131
# 💾 Backup guardado en fila 110 - 20251107_024150
# 💾 Backup guardado en fila 120 - 20251107_024208
# 💾 Backup guardado en fila 130 - 20251107_024227
# 💾 Backup guardado en fila 140 - 20251107_024246
# 💾 Backup guardado en fila 150 - 20251107_024304
# 💾 Backup guardado en fila 160 - 20251107_024322
# 💾 Backup guardado en fila 170 - 20251107_024340
# 💾 Backup guardado en fila 180 - 20251107_024358
# 💾 Backup guardado en fila 190 - 20251107_024416
# 💾 Backup guardado en fila 200 - 20251107_024436
# 💾 Backup guardado en fila 210 - 20251107_024455
# 💾 Backup guardado en fila 220 - 20251107_024513
# 💾 Backup guardado en fila 230 - 20251107_024531
# 💾 Backup guardado en fila 240 - 20251107_024549
# 💾 Backup guardado en fila 250 - 20251107_024607
# 💾 Backup guardado en fila 260 - 20251107_024624
# 💾 Backup guardado en fila 270 - 20251107_024643
# 💾 Backup guardado en fila 280 - 20251107_024701
# 💾 Backup guardado en fila 290 - 20251107_024720
# 💾 Backup guardado en fila 300 - 20251107_024739
# 💾 Backup guardado en fila 310 - 20251107_024829
# 💾 Backup guardado en fila 320 - 20251107_024848
# 💾 Backup guardado en fila 330 - 20251107_024907
# 💾 Backup guardado en fila 340 - 20251107_024926
# 💾 Backup guardado en fila 350 - 20251107_024945
# 💾 Backup guardado en fila 360 - 20251107_025004
# 💾 Backup guardado en fila 370 - 20251107_025023
# 💾 Backup guardado en fila 380 - 20251107_025043
# 💾 Backup guardado en fila 390 - 20251107_025100
# 💾 Backup guardado en fila 400 - 20251107_025118
# 💾 Backup guardado en fila 410 - 20251107_025138
# ❌ Error: Connection error.
# 💾 Backup guardado en fila 420 - 20251107_111525
# 💾 Backup guardado en fila 430 - 20251107_111551
# 💾 Backup guardado en fila 440 - 20251107_111611
# ✅ Proceso completado en 517.98 minutos.

# %% [markdown]
# # Guardar resultados completos

# %%
df.to_csv("../data/paper_outputs/df_fiscal_scored_true.csv", index=False)

# %%
df.head(5)
# Out:
#                                                title doc_type  doc_id  year  \
# 0  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 1  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 2  Informe CF N° 002-2016 – Opinión del Consejo F...  Informe     2.0  2016
# 3  Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
# 4  Informe CF N° 003-2016 – Opinión del Consejo F...  Informe     3.0  2016
#
#         date  page  paragraph_id  \
# 0 2016-04-15     2            12
# 1 2016-04-15     3            13
# 2 2016-04-15     3            15
# 3 2016-06-23     3             2
# 4 2016-06-23     3            21
#
#                                                 text fiscal_risk_score  \
# 0  Sin embargo, en relación a las previsiones de ...                 4
# 1  Teniendo en cuenta lo expuesto, el CF opina qu...                 3
# 2  El CF advierte que el escenario internacional ...                 4
# 3  Por último, cabe indicar que el numeral 8.4 de...                 4
# 4   El listado con los gobiernos regionales y loc...                 3
#
#   risk_index
# 0        0.8
# 1        0.6
# 2        0.8
# 3        0.8
# 4        0.6

# %% [markdown]
# # Filtering new docs

# %%
# Assuming 'date' column is already in datetime format
#filtered_df = df[df['date'].isin([pd.to_datetime('2025-08-29'), pd.to_datetime('2025-10-21')])]

# %%
#filtered_df
# Out:
#                                                  title    doc_type  doc_id  \
# 424  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 425  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 426  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 427  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 428  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 429  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 430  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 431  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 432  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 433  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 434  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 435  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 436  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 437  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 438  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 439  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 440  Informe N° 04-2025-CF – Opinión del Consejo Fi...     Informe     4.0
# 441  Comunicado N° 06-2025-CF – El Consejo Fiscal a...  Comunicado     6.0
# 442  Comunicado N° 06-2025-CF – El Consejo Fiscal a...  Comunicado     6.0
# 443  Comunicado N° 06-2025-CF – El Consejo Fiscal a...  Comunicado     6.0
# 444  Comunicado N° 06-2025-CF – El Consejo Fiscal a...  Comunicado     6.0
# 445  Comunicado N° 06-2025-CF – El Consejo Fiscal a...  Comunicado     6.0
# 446  Comunicado N° 06-2025-CF – El Consejo Fiscal a...  Comunicado     6.0
# 447  Comunicado N° 06-2025-CF – El Consejo Fiscal a...  Comunicado     6.0
#
#      year       date  page  paragraph_id  \
# 424  2025 2025-08-29     1            66
# 425  2025 2025-08-29     1            68
# 426  2025 2025-08-29     2            69
# 427  2025 2025-08-29     2            74
# 428  2025 2025-08-29     7            23
# 429  2025 2025-08-29     9             3
# 430  2025 2025-08-29     9             4
# 431  2025 2025-08-29    12            25
# 432  2025 2025-08-29    12            27
# 433  2025 2025-08-29    12            45
# 434  2025 2025-08-29    13            47
# 435  2025 2025-08-29    13            49
# 436  2025 2025-08-29    14            26
# 437  2025 2025-08-29    15            52
# 438  2025 2025-08-29    15            56
# 439  2025 2025-08-29    16            44
# 440  2025 2025-08-29    17            30
# 441  2025 2025-10-21     1            21
# 442  2025 2025-10-21     3            10
# 443  2025 2025-10-21     3            11
# 444  2025 2025-10-21     5             5
# 445  2025 2025-10-21     5             6
# 446  2025 2025-10-21     6             2
# 447  2025 2025-10-21     6            22
#
#                                                   text fiscal_risk_score  \
# 424  El CF alerta que, producto de la ausencia de m...                 4
# 425  El CF advierte que la senda de proyección del ...                 4
# 426  El CF considera que, en ausencia de medidas co...                 4
# 427  El CF identifica un conjunto de riesgos fiscal...                 4
# 428  Sobre la actividad económica local, el CF cons...                 4
# 429  El CF exhorta a que en la versión final del MM...                 2
# 430  En un contexto en el que el crecimiento potenc...                 2
# 431  Ante este contexto, el CF reitera su exhortaci...                 4
# 432  Más aún, la materialización de cualquier presi...                 4
# 433  Sobre la proyección del gasto público para 202...                 4
# 434  Para 2026, año para el cual se está formulando...                 1
# 435  El CF nota que en el rubro remuneraciones el i...                 2
# 436  Para facilitar el seguimiento al cumplimiento ...                 4
# 437  En ausencia de medidas concretas de consolidac...                 4
# 438  Respecto a la proyección de la deuda pública, ...                 5
# 439  Más allá del horizonte de proyección del MMM, ...                 4
# 440  En cuanto al análisis de riesgos fiscales, el ...                 4
# 441  El Consejo Fiscal (CF), en el marco de su mand...                 5
# 442  Dado que estas medidas generan impactos fiscal...                 5
# 443  Las presiones fiscales ya generadas por leyes ...                 5
# 444  El Consejo Fiscal considera que el TC podría e...                 3
# 445  El CF subraya que la responsabilidad por la pr...                 5
# 446  Asimismo, en adelante, recomienda que toda nor...                 5
# 447  Finalmente, el CF enfatiza que la disciplina f...                 5
#
#     risk_index
# 424        0.8
# 425        0.8
# 426        0.8
# 427        0.8
# 428        0.8
# 429        0.4
# 430        0.4
# 431        0.8
# 432        0.8
# 433        0.8
# 434        0.2
# 435        0.4
# 436        0.8
# 437        0.8
# 438        1.0
# 439        0.8
# 440        0.8
# 441        1.0
# 442        1.0
# 443        1.0
# 444        0.6
# 445        1.0
# 446        1.0
# 447        1.0

# %%
#filtered_df.to_csv('scored_new_added_docs.csv', index=False)

# %%
df.to_csv('../data/paper_outputs/df_fiscal_scored_true.csv', index=False)

# %% [markdown]
# # load csv

# %%
df = pd.read_csv("llm_output_paragraphs.csv")

# %% [markdown]
# # Fleeting inspect

# %%
df
# Out:
#       paragraph_num                                               text  \
# 0                 1  El 21 de mayo de 2022 se publicó en el diario ...
# 1                 2  El Consejo Fiscal (CF) considera que esta norm...
# 2                 3  En cuanto a los efectos fiscales, en el corto ...
# 3                 4  En cuanto a los efectos macroeconómicos, más a...
# 4                 5  Por ello, el CF observa con preocupación que s...
# ...             ...                                                ...
# 1670           1671                                                 4.
# 1671           1672  En cuanto al cumplimiento de las reglas fiscal...
# 1672           1673  Sobre el uso de calificaciones crediticias par...
# 1673           1674  En cuanto a la deuda de la MML, el CF reitera ...
# 1674           1675  Finalmente, el CF recomienda incluir en el IAE...
#
#       length page_range                                 pdf_filename  \
# 0        777        1-2               2-ComunicadoCF-RetiroAFP-1.pdf
# 1        533        1-2               2-ComunicadoCF-RetiroAFP-1.pdf
# 2        913        1-2               2-ComunicadoCF-RetiroAFP-1.pdf
# 3        834        1-2               2-ComunicadoCF-RetiroAFP-1.pdf
# 4        859        1-2               2-ComunicadoCF-RetiroAFP-1.pdf
# ...      ...        ...                                          ...
# 1670       2        5-6  Pronunciamiento_Subnacional_2024_240624.pdf
# 1671     793        5-6  Pronunciamiento_Subnacional_2024_240624.pdf
# 1672     377        5-6  Pronunciamiento_Subnacional_2024_240624.pdf
# 1673     593        5-6  Pronunciamiento_Subnacional_2024_240624.pdf
# 1674     506        5-6  Pronunciamiento_Subnacional_2024_240624.pdf
#
#                                               doc_title    doc_type  \
# 0     Comunicado N° 02-2022-CF Comunicado del Consej...  Comunicado
# 1     Comunicado N° 02-2022-CF Comunicado del Consej...  Comunicado
# 2     Comunicado N° 02-2022-CF Comunicado del Consej...  Comunicado
# 3     Comunicado N° 02-2022-CF Comunicado del Consej...  Comunicado
# 4     Comunicado N° 02-2022-CF Comunicado del Consej...  Comunicado
# ...                                                 ...         ...
# 1670  Informe N° 02-2024-CF – Opinión del Consejo Fi...     Informe
# 1671  Informe N° 02-2024-CF – Opinión del Consejo Fi...     Informe
# 1672  Informe N° 02-2024-CF – Opinión del Consejo Fi...     Informe
# 1673  Informe N° 02-2024-CF – Opinión del Consejo Fi...     Informe
# 1674  Informe N° 02-2024-CF – Opinión del Consejo Fi...     Informe
#
#       doc_number                     date  year  ...  pdf_type  \
# 0            2.0  2022-05-24T00:00:00.000  2022  ...  editable
# 1            2.0  2022-05-24T00:00:00.000  2022  ...  editable
# 2            2.0  2022-05-24T00:00:00.000  2022  ...  editable
# 3            2.0  2022-05-24T00:00:00.000  2022  ...  editable
# 4            2.0  2022-05-24T00:00:00.000  2022  ...  editable
# ...          ...                      ...   ...  ...       ...
# 1670         2.0  2024-07-05T00:00:00.000  2024  ...  editable
# 1671         2.0  2024-07-05T00:00:00.000  2024  ...  editable
# 1672         2.0  2024-07-05T00:00:00.000  2024  ...  editable
# 1673         2.0  2024-07-05T00:00:00.000  2024  ...  editable
# 1674         2.0  2024-07-05T00:00:00.000  2024  ...  editable
#
#                                                 pdf_url  \
# 0     https://cf.gob.pe/wp-content/uploads/2022/05/2...
# 1     https://cf.gob.pe/wp-content/uploads/2022/05/2...
# 2     https://cf.gob.pe/wp-content/uploads/2022/05/2...
# 3     https://cf.gob.pe/wp-content/uploads/2022/05/2...
# 4     https://cf.gob.pe/wp-content/uploads/2022/05/2...
# ...                                                 ...
# 1670  https://cf.gob.pe/wp-content/uploads/2024/07/P...
# 1671  https://cf.gob.pe/wp-content/uploads/2024/07/P...
# 1672  https://cf.gob.pe/wp-content/uploads/2024/07/P...
# 1673  https://cf.gob.pe/wp-content/uploads/2024/07/P...
# 1674  https://cf.gob.pe/wp-content/uploads/2024/07/P...
#
#                                                page_url fiscal_risk_score  \
# 0     https://cf.gob.pe/documentos/comunicados/comun...               2.0
# 1     https://cf.gob.pe/documentos/comunicados/comun...               4.0
# 2     https://cf.gob.pe/documentos/comunicados/comun...               2.0
# 3     https://cf.gob.pe/documentos/comunicados/comun...               4.0
# 4     https://cf.gob.pe/documentos/comunicados/comun...               2.0
# ...                                                 ...               ...
# 1670  https://cf.gob.pe/documentos/informe-n-02-2024...               2.0
# 1671  https://cf.gob.pe/documentos/informe-n-02-2024...               4.0
# 1672  https://cf.gob.pe/documentos/informe-n-02-2024...               4.0
# 1673  https://cf.gob.pe/documentos/informe-n-02-2024...               4.0
# 1674  https://cf.gob.pe/documentos/informe-n-02-2024...               4.0
#
#      risk_index  normalized  original_paragraph_num chunk_index  total_chunks  \
# 0           0.4         NaN                     NaN         NaN           NaN
# 1           0.8         NaN                     NaN         NaN           NaN
# 2           0.4         NaN                     NaN         NaN           NaN
# 3           0.8         NaN                     NaN         NaN           NaN
# 4           0.4         NaN                     NaN         NaN           NaN
# ...         ...         ...                     ...         ...           ...
# 1670        0.4        True                  1488.0         1.0           2.0
# 1671        0.8         NaN                     NaN         NaN           NaN
# 1672        0.8         NaN                     NaN         NaN           NaN
# 1673        0.8         NaN                     NaN         NaN           NaN
# 1674        0.8         NaN                     NaN         NaN           NaN
#
#       merged_with
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1670          NaN
# 1671          NaN
# 1672          NaN
# 1673          NaN
# 1674          NaN
#
# [1675 rows x 22 columns]

# %%
df["fiscal_risk_score"].value_counts(dropna=False).sort_index()
# Out:
# fiscal_risk_score
# 1.0     84
# 2.0    520
# 3.0    188
# 4.0    808
# 5.0     74
# NaN      1
# Name: count, dtype: int64

# %%
df["risk_index"].describe()
# Out:
# count    1674.000000
# mean        0.632019
# std         0.214094
# min         0.200000
# 25%         0.400000
# 50%         0.800000
# 75%         0.800000
# max         1.000000
# Name: risk_index, dtype: float64

# %% [markdown]
# # ----------------------------------------------
# # 5. Agregar score promedio por fecha
# # ----------------------------------------------

# %% [markdown]
# # Aggregation

# %%
df_doc_avg = df.groupby(['doc_title', 'date']).agg(
    avg_risk_score=('fiscal_risk_score', 'mean'),
    avg_risk_index=('risk_index', 'mean'),
    n_paragraphs=('fiscal_risk_score', 'count')
).reset_index()

# %%
df_doc_avg
# Out:
#                                             doc_title  \
# 0   Comunicado N° 01-2022-CF Comunicado del Consej...
# 1   Comunicado N° 01-2023-CF Comunicado del Consej...
# 2   Comunicado N° 01-2024-CF – El Consejo Fiscal a...
# 3   Comunicado N° 01-2025-CF – El Consejo Fiscal e...
# 4   Comunicado N° 02-2022-CF Comunicado del Consej...
# ..                                                ...
# 72  Informe N° 05-2024-CF – Opinión del Consejo Fi...
# 73  Informe N° 06-2021-CF Opinión del Consejo Fisc...
# 74  Informe N°002-2019-CF Opinión del Consejo Fisc...
# 75  Informe N°003-2019-CF Opinión del Consejo Fisc...
# 76  Informe N°004-2019-CF Opinión del Consejo Fisc...
#
#                        date  avg_risk_score  avg_risk_index  n_paragraphs
# 0   2022-01-14T00:00:00.000        3.857143        0.771429             7
# 1   2023-03-02T00:00:00.000        3.333333        0.666667             6
# 2   2024-02-01T00:00:00.000        2.736842        0.547368            19
# 3   2025-01-20T00:00:00.000        3.312500        0.662500            32
# 4   2022-05-24T00:00:00.000        2.800000        0.560000             5
# ..                      ...             ...             ...           ...
# 72  2024-08-23T00:00:00.000        3.200000        0.640000            65
# 73  2021-12-20T00:00:00.000        2.647059        0.529412            17
# 74  2019-05-21T00:00:00.000        2.684211        0.536842            19
# 75  2019-06-06T00:00:00.000        2.875000        0.575000            16
# 76  2019-08-26T00:00:00.000        3.200000        0.640000            25
#
# [77 rows x 5 columns]

# %%
df_score_dist = (
    df.pivot_table(index=['doc_title', 'date'], 
                   columns='fiscal_risk_score', 
                   values='text', 
                   aggfunc='count', 
                   fill_value=0)
    .reset_index()
    .rename(columns={1: 'score_1', 2: 'score_2', 3: 'score_3', 4: 'score_4', 5: 'score_5'})
)

# %%
df_score_dist
# Out:
# fiscal_risk_score                                          doc_title  \
# 0                  Comunicado N° 01-2022-CF Comunicado del Consej...
# 1                  Comunicado N° 01-2023-CF Comunicado del Consej...
# 2                  Comunicado N° 01-2024-CF – El Consejo Fiscal a...
# 3                  Comunicado N° 01-2025-CF – El Consejo Fiscal e...
# 4                  Comunicado N° 02-2022-CF Comunicado del Consej...
# ..                                                               ...
# 72                 Informe N° 05-2024-CF – Opinión del Consejo Fi...
# 73                 Informe N° 06-2021-CF Opinión del Consejo Fisc...
# 74                 Informe N°002-2019-CF Opinión del Consejo Fisc...
# 75                 Informe N°003-2019-CF Opinión del Consejo Fisc...
# 76                 Informe N°004-2019-CF Opinión del Consejo Fisc...
#
# fiscal_risk_score                     date  score_1  score_2  score_3  \
# 0                  2022-01-14T00:00:00.000        0        1        0
# 1                  2023-03-02T00:00:00.000        0        2        0
# 2                  2024-02-01T00:00:00.000        2        8        3
# 3                  2025-01-20T00:00:00.000        1       10        2
# 4                  2022-05-24T00:00:00.000        0        3        0
# ..                                     ...      ...      ...      ...
# 72                 2024-08-23T00:00:00.000        0       25        3
# 73                 2021-12-20T00:00:00.000        1        8        5
# 74                 2019-05-21T00:00:00.000        2        7        5
# 75                 2019-06-06T00:00:00.000        2        6        0
# 76                 2019-08-26T00:00:00.000        2        6        3
#
# fiscal_risk_score  score_4  score_5
# 0                        5        1
# 1                        4        0
# 2                        5        1
# 3                       16        3
# 4                        2        0
# ..                     ...      ...
# 72                      36        1
# 73                       2        1
# 74                       5        0
# 75                       8        0
# 76                      13        1
#
# [77 rows x 7 columns]

# %%
score_cols = ['score_1', 'score_2', 'score_3', 'score_4', 'score_5']
df_score_dist[score_cols] = df_score_dist[score_cols].div(df_score_dist[score_cols].sum(axis=1), axis=0)

# %%
df_score_dist
# Out:
# fiscal_risk_score                                          doc_title  \
# 0                  Comunicado N° 01-2022-CF Comunicado del Consej...
# 1                  Comunicado N° 01-2023-CF Comunicado del Consej...
# 2                  Comunicado N° 01-2024-CF – El Consejo Fiscal a...
# 3                  Comunicado N° 01-2025-CF – El Consejo Fiscal e...
# 4                  Comunicado N° 02-2022-CF Comunicado del Consej...
# ..                                                               ...
# 72                 Informe N° 05-2024-CF – Opinión del Consejo Fi...
# 73                 Informe N° 06-2021-CF Opinión del Consejo Fisc...
# 74                 Informe N°002-2019-CF Opinión del Consejo Fisc...
# 75                 Informe N°003-2019-CF Opinión del Consejo Fisc...
# 76                 Informe N°004-2019-CF Opinión del Consejo Fisc...
#
# fiscal_risk_score                     date   score_1   score_2   score_3  \
# 0                  2022-01-14T00:00:00.000  0.000000  0.142857  0.000000
# 1                  2023-03-02T00:00:00.000  0.000000  0.333333  0.000000
# 2                  2024-02-01T00:00:00.000  0.105263  0.421053  0.157895
# 3                  2025-01-20T00:00:00.000  0.031250  0.312500  0.062500
# 4                  2022-05-24T00:00:00.000  0.000000  0.600000  0.000000
# ..                                     ...       ...       ...       ...
# 72                 2024-08-23T00:00:00.000  0.000000  0.384615  0.046154
# 73                 2021-12-20T00:00:00.000  0.058824  0.470588  0.294118
# 74                 2019-05-21T00:00:00.000  0.105263  0.368421  0.263158
# 75                 2019-06-06T00:00:00.000  0.125000  0.375000  0.000000
# 76                 2019-08-26T00:00:00.000  0.080000  0.240000  0.120000
#
# fiscal_risk_score   score_4   score_5
# 0                  0.714286  0.142857
# 1                  0.666667  0.000000
# 2                  0.263158  0.052632
# 3                  0.500000  0.093750
# 4                  0.400000  0.000000
# ..                      ...       ...
# 72                 0.553846  0.015385
# 73                 0.117647  0.058824
# 74                 0.263158  0.000000
# 75                 0.500000  0.000000
# 76                 0.520000  0.040000
#
# [77 rows x 7 columns]

# %%
df_doc_summary = pd.merge(df_doc_avg, df_score_dist, on=['doc_title', 'date'])

# %%
df_doc_summary
# Out:
#                                             doc_title  \
# 0   Comunicado N° 01-2022-CF Comunicado del Consej...
# 1   Comunicado N° 01-2023-CF Comunicado del Consej...
# 2   Comunicado N° 01-2024-CF – El Consejo Fiscal a...
# 3   Comunicado N° 01-2025-CF – El Consejo Fiscal e...
# 4   Comunicado N° 02-2022-CF Comunicado del Consej...
# ..                                                ...
# 72  Informe N° 05-2024-CF – Opinión del Consejo Fi...
# 73  Informe N° 06-2021-CF Opinión del Consejo Fisc...
# 74  Informe N°002-2019-CF Opinión del Consejo Fisc...
# 75  Informe N°003-2019-CF Opinión del Consejo Fisc...
# 76  Informe N°004-2019-CF Opinión del Consejo Fisc...
#
#                        date  avg_risk_score  avg_risk_index  n_paragraphs  \
# 0   2022-01-14T00:00:00.000        3.857143        0.771429             7
# 1   2023-03-02T00:00:00.000        3.333333        0.666667             6
# 2   2024-02-01T00:00:00.000        2.736842        0.547368            19
# 3   2025-01-20T00:00:00.000        3.312500        0.662500            32
# 4   2022-05-24T00:00:00.000        2.800000        0.560000             5
# ..                      ...             ...             ...           ...
# 72  2024-08-23T00:00:00.000        3.200000        0.640000            65
# 73  2021-12-20T00:00:00.000        2.647059        0.529412            17
# 74  2019-05-21T00:00:00.000        2.684211        0.536842            19
# 75  2019-06-06T00:00:00.000        2.875000        0.575000            16
# 76  2019-08-26T00:00:00.000        3.200000        0.640000            25
#
#      score_1   score_2   score_3   score_4   score_5
# 0   0.000000  0.142857  0.000000  0.714286  0.142857
# 1   0.000000  0.333333  0.000000  0.666667  0.000000
# 2   0.105263  0.421053  0.157895  0.263158  0.052632
# 3   0.031250  0.312500  0.062500  0.500000  0.093750
# 4   0.000000  0.600000  0.000000  0.400000  0.000000
# ..       ...       ...       ...       ...       ...
# 72  0.000000  0.384615  0.046154  0.553846  0.015385
# 73  0.058824  0.470588  0.294118  0.117647  0.058824
# 74  0.105263  0.368421  0.263158  0.263158  0.000000
# 75  0.125000  0.375000  0.000000  0.500000  0.000000
# 76  0.080000  0.240000  0.120000  0.520000  0.040000
#
# [77 rows x 10 columns]

# %% [markdown]
# # ----------------------------------------------
# # 6. Visualizar índice fiscal
# # ----------------------------------------------

# %% [markdown]
# # CMA

# %%
df_doc_summary = df_doc_summary.sort_values("date")

# %%
# Calcula la media móvil centrada con ventana de 3 documentos
df_doc_summary["cma_risk_index"] = df_doc_summary["avg_risk_score"].rolling(window=3, center=True).mean()

# %% [markdown]
# $$
# \text{CMA}_t = \frac{4X_{t-1} + 2X_t + X_{t+1}}{7}
# $$

# %% [markdown]
# # Áreas apiladas

# %%
print(df_doc_summary['date'].dtype)
# Out:
# object

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Asegurar que la columna 'date' sea datetime
df_doc_summary['date'] = pd.to_datetime(df_doc_summary['date'], errors='coerce')

# Asegurar orden por fecha
df_doc_summary = df_doc_summary.sort_values("date").reset_index(drop=True)

# Crear columna string para eje X
df_doc_summary['date_str'] = df_doc_summary['date'].dt.strftime('%Y-%m-%d')

# Pesos del suavizamiento
weights = np.array([1, 2, 1])

# Aplicar CMA con bordes extendidos
for col in ['score_1', 'score_2', 'score_3', 'score_4', 'score_5']:
    series = df_doc_summary[col].copy()

    middle_cma = (
        series.rolling(window=3, center=True)
        .apply(lambda x: np.dot(x, weights) / 4, raw=True)
    )

    # Bordes
    first = series.iloc[0]
    second = series.iloc[1]
    first_smoothed = (3 * first + second) / 4

    last = series.iloc[-1]
    penultimate = series.iloc[-2]
    last_smoothed = (3 * last + penultimate) / 4

    # Insertar bordes
    middle_cma.iloc[0] = first_smoothed
    middle_cma.iloc[-1] = last_smoothed

    df_doc_summary[f'{col}_cma'] = middle_cma

# Configuración para el gráfico
cols_cma = ['score_1_cma', 'score_2_cma', 'score_3_cma', 'score_4_cma', 'score_5_cma']
labels = ['1 (bajo)', '2', '3', '4', '5 (alto)']
colors = ['#40312C', '#634C44', '#ff8575', '#ED2939', '#1F305E']

# Crear figura
fig, ax = plt.subplots(figsize=(14, 6))

# Áreas apiladas suavizadas
ax.stackplot(df_doc_summary['date_str'], 
             *[df_doc_summary[col] for col in cols_cma],
             labels=labels,
             colors=colors)

# Etiquetas
ax.set_ylabel("Proporción de Párrafos", fontsize=16)

# Eje X
ax.tick_params(axis='x', labelrotation=90, labelsize=12)

# Eje Y con 2 decimales
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
ax.tick_params(axis='y', labelsize=12)

# Rejilla estética
ax.grid(True, color='#f5f5f5', alpha=0.3, linewidth=1)

# Leyenda personalizada
legend = ax.legend(loc='upper left', frameon=True)
legend.get_frame().set_facecolor('#f5f5f5')
legend.get_frame().set_alpha(0.5)
legend.get_frame().set_edgecolor('#f5f5f5')  # contorno sin transparencia
legend.get_frame().set_linewidth(2)  # grosor del contorno

# Margen automático
plt.tight_layout()

# Guardar gráfico
plt.savefig("../figures/paper/Fig_Distribucion.png", dpi=300)
plt.show()

# %% [markdown]
# # Index

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# Calcular índice de tono fiscal
df_doc_summary["fiscal_tone_index"] = (3 - df_doc_summary["avg_risk_score"]) / 2

# Suavizamiento CMA (1-2-1)
weights = np.array([1, 2, 1])
series = df_doc_summary["fiscal_tone_index"].copy()

cma = series.rolling(window=3, center=True).apply(lambda x: np.dot(x, weights) / 4, raw=True)
cma.iloc[0] = (3 * series.iloc[0] + series.iloc[1]) / 4
cma.iloc[-1] = (3 * series.iloc[-1] + series.iloc[-2]) / 4

df_doc_summary["fiscal_tone_index_cma"] = cma

# Graficar
fig, ax = plt.subplots(figsize=(14, 6))

# Serie original (transparente)
ax.plot(df_doc_summary["date_str"], df_doc_summary["fiscal_tone_index"],
        label="Tono Fiscal", linestyle='--',
        marker='o', alpha=0.25, color="#40312C")

# Serie suavizada (principal)
ax.plot(df_doc_summary["date_str"], df_doc_summary["fiscal_tone_index_cma"],
        label="Tono Fiscal (Promedio Móvil)", linewidth=2, color="#634C44")

# Línea horizontal en 0 (tono neutral)
ax.axhline(0, color='#292929', linestyle='-', linewidth=1)

# Eje Y
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
ax.tick_params(axis='y', labelsize=12)

# Eje X
ax.tick_params(axis='x', labelrotation=90, labelsize=12)

# Rejilla solo cada 2 fechas
x_ticks = np.arange(len(df_doc_summary["date_str"]))
ax.set_xticks(x_ticks)  # etiquetas en todas las fechas
ax.grid(False)  # desactivar rejilla por defecto

# Dibujar palos verticales cada 2 ticks
for i in range(0, len(x_ticks), 2):
    ax.axvline(x=i, color='#f5f5f5', linewidth=1, zorder=0)

# Etiqueta eje Y
ax.set_ylabel("Índice de Tono Fiscal", fontsize=16)

# Leyenda personalizada
legend = ax.legend(loc='upper right', frameon=True)
legend.get_frame().set_facecolor('white')
legend.get_frame().set_alpha(0.5)
legend.get_frame().set_edgecolor('#f5f5f5')
legend.get_frame().set_linewidth(2.5)

# Ajuste final
plt.tight_layout()

# Guardar y mostrar
plt.savefig("../figures/paper/Fig_Tone.png", dpi=300)
plt.show()

# %%
print("Rango de avg_risk_score:", df_doc_summary["avg_risk_score"].min(), "a", df_doc_summary["avg_risk_score"].max())
# Out:
# Rango de avg_risk_score: 1.0 a 5.0

# %%
df_doc_summary.to_csv("../data/paper_outputs/df_fiscal_tone_true.csv")
